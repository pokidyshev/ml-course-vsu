# %% [markdown]
# # Визуализация деревьев

# %%
# You need to install pydotplus and graphviz firstly!

import pydotplus
from sklearn.datasets import load_iris
from sklearn import tree

# Data Collection
X = [ [180, 15,0],     
      [177, 42,0],
      [136, 35,1],
      [174, 65,0],
      [141, 28,1]]

Y = ['man', 'woman', 'woman', 'man', 'woman']    

data_feature_names = [ 'height', 'hair length', 'voice pitch' ]

import pandas as pd

df = pd.DataFrame(data=X)
df.columns = data_feature_names
df['target'] = Y
df
# Out:
#    height  hair length  voice pitch target
# 0     180           15            0    man
# 1     177           42            0  woman
# 2     136           35            1  woman
# 3     174           65            0    man
# 4     141           28            1  woman

# %%
# Training
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,Y)

# Visualize data
dot_data = tree.export_graphviz(clf,
                                feature_names=data_feature_names,
                                out_file=None,
                                filled=True,
                                rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data)

from IPython.display import Image
Image(graph.create_jpg())
